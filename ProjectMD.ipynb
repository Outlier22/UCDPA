# %%
import pandas as pd

# %%
pahours = pd.read_csv('Project_CSV.csv')
pahours
# Out:
#      SU Ref Basic Hrs SAT Hrs    DON    UON AntiSocial Hrs Pub Hol Hrs  \
# 0       1.0         6    -      -      -                 8           5
# 1       2.0        19    -      -      -                 2        -
# 2       3.0      -       -      -      -              -              4
# 3       4.0         6    -      -      -              -              2
# 4       5.0         2    -      -      -              -           -
# ..      ...       ...     ...    ...    ...            ...         ...
# 995   996.0        89    -      -      -              -           -
# 996   997.0       298    -      -      -              -           -
# 997   998.0        60    -      -      -              -           -
# 998   999.0       163    -      -      -              -              1
# 999     NaN       NaN     NaN    NaN    NaN            NaN         NaN
#
#     Sunday Hrs  Total Hrs  Hours per week Hours per week category AS/PH/SUN %  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
pahours = pd.read_csv('Project_CSV.csv')
pahours.head()
# Out:
#    SU Ref Basic Hrs SAT Hrs    DON    UON AntiSocial Hrs Pub Hol Hrs  \
# 0     1.0         6    -      -      -                 8           5
# 1     2.0        19    -      -      -                 2        -
# 2     3.0      -       -      -      -              -              4
# 3     4.0         6    -      -      -              -              2
# 4     5.0         2    -      -      -              -           -
#
#   Sunday Hrs  Total Hrs  Hours per week Hours per week category AS/PH/SUN %  \
# 0        132      150.0             5.0             Under 5 Hrs         96%
# 1        250      270.0             9.0                6-10 Hrs         93%
# 2        112      116.0             4.0             Under 5 Hrs        100%
# 3         50       58.0             2.0             Under 5 Hrs         90%
# 4         13       15.0             0.0             Under 5 Hrs         87%
#
#           Premium Hours
# 0  Over 40% premium hrs
# 1  Over 40% premium hrs
# ...

# %%
plt.scatter(x=pahours['SU Ref'], y=pahours['Hours per week'], s=2)
plt.title('Service User Hours Per Week')
plt.xlabel('Number of Service User')
plt.ylabel('Hours per Week')
# Out:
# Text(0, 0.5, 'Hours per Week')

# %%
sns.scatterplot(data=pahours, x='SU Ref', y='Hours per week', size='SU Ref')
# Out:
# <AxesSubplot:xlabel='SU Ref', ylabel='Hours per week'>

# %%
plt.barh(pahours['SU Ref'], pahours['Hours per week'])
plt.title('Service User Hours Per Week')
plt.xlabel('Number of Service User')
plt.ylabel('Hours per Week')
# Out:
# Text(0, 0.5, 'Hours per Week')

# %%
sns.barplot(data=pahours, x='SU Ref', y='Hours per week')
# Out:
# <AxesSubplot:xlabel='SU Ref', ylabel='Hours per week'>

# %%
plt.bar(pahours['SU Ref'], pahours['Total Hrs'], pahours['Hours per week'])
# Out:
# <BarContainer object of 1000 artists>

# %%
sns.histplot(data=pahours, y='Total Hrs')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Total Hrs'>

# %%
sns.jointplot(data=pahours, x='SU Ref', y='Total Hrs')

# %%
pahours.dtypes
# Out:
# SU Ref                     float64
# Basic Hrs                   object
# SAT Hrs                     object
# DON                         object
# UON                         object
# AntiSocial Hrs              object
# Pub Hol Hrs                 object
# Sunday Hrs                  object
# Total Hrs                  float64
# Hours per week             float64
# Hours per week category     object
# AS/PH/SUN %                 object
# Premium Hours               object
# dtype: object

# %%
pahours.head(3)
# Out:
#    SU Ref  Basic Hrs   SAT Hrs    DON    UON   AntiSocial Hrs   Pub Hol Hrs   \
# 0     1.0           6      -      -      -                   8             5
# 1     2.0          19      -      -      -                   2          -
# 2     3.0        -         -      -      -                -                4
#
#    Sunday Hrs   Total Hrs   Hours per week Hours per week category  \
# 0          132         150             5.0             Under 5 Hrs
# 1          250         270             9.0                6-10 Hrs
# 2          112         116             4.0             Under 5 Hrs
#
#   AS/PH/SUN %         Premium Hours
# 0         96%  Over 40% premium hrs
# 1         93%  Over 40% premium hrs
# 2        100%  Over 40% premium hrs

# %%
# Describing the table
pahours.describe
# Out:
# <bound method NDFrame.describe of      SU Ref Basic Hrs SAT Hrs    DON    UON AntiSocial Hrs Pub Hol Hrs  \
# 0       1.0         6    -      -      -                 8           5
# 1       2.0        19    -      -      -                 2        -
# 2       3.0      -       -      -      -              -              4
# 3       4.0         6    -      -      -              -              2
# 4       5.0         2    -      -      -              -           -
# ..      ...       ...     ...    ...    ...            ...         ...
# 995   996.0        89    -      -      -              -           -
# 996   997.0       298    -      -      -              -           -
# 997   998.0        60    -      -      -              -           -
# 998   999.0       163    -      -      -              -              1
# 999     NaN       NaN     NaN    NaN    NaN            NaN         NaN
#
#     Sunday Hrs  Total Hrs  Hours per week Hours per week category AS/PH/SUN %  \
# ...

# %%
pahours.compare
# Out:
# <bound method DataFrame.compare of      SU Ref Basic Hrs SAT Hrs    DON    UON AntiSocial Hrs Pub Hol Hrs  \
# 0       1.0         6    -      -      -                 8           5
# 1       2.0        19    -      -      -                 2        -
# 2       3.0      -       -      -      -              -              4
# 3       4.0         6    -      -      -              -              2
# 4       5.0         2    -      -      -              -           -
# ..      ...       ...     ...    ...    ...            ...         ...
# 995   996.0        89    -      -      -              -           -
# 996   997.0       298    -      -      -              -           -
# 997   998.0        60    -      -      -              -           -
# 998   999.0       163    -      -      -              -              1
# 999     NaN       NaN     NaN    NaN    NaN            NaN         NaN
#
#     Sunday Hrs  Total Hrs  Hours per week Hours per week category AS/PH/SUN %  \
# ...

# %%
# Setting the index as SU Ref
SUR=pahours.reset_index('Su Ref')
SURef
# Out:
#        Basic Hrs SAT Hrs    DON    UON AntiSocial Hrs Pub Hol Hrs Sunday Hrs  \
# SU Ref
# 1.0            6    -      -      -                 8           5        132
# 2.0           19    -      -      -                 2        -           250
# 3.0         -       -      -      -              -              4        112
# 4.0            6    -      -      -              -              2         50
# 5.0            2    -      -      -              -           -            13
# ...          ...     ...    ...    ...            ...         ...        ...
# 996.0         89    -      -      -              -           -          -
# 997.0        298    -      -      -              -           -          -
# 998.0         60    -      -      -              -           -          -
# 999.0        163    -      -      -              -              1       -
# NaN          NaN     NaN    NaN    NaN            NaN         NaN        NaN
#
# ...

# %%
pahours.head(5)
# Out:
#    SU Ref  Basic Hrs   SAT Hrs    DON    UON   AntiSocial Hrs   Pub Hol Hrs   \
# 0     1.0           6      -      -      -                   8             5
# 1     2.0          19      -      -      -                   2          -
# 2     3.0        -         -      -      -                -                4
# 3     4.0           6      -      -      -                -                2
# 4     5.0           2      -      -      -                -             -
#
#    Sunday Hrs   Total Hrs   Hours per week Hours per week category  \
# 0          132         150             5.0             Under 5 Hrs
# 1          250         270             9.0                6-10 Hrs
# 2          112         116             4.0             Under 5 Hrs
# 3           50          58             2.0             Under 5 Hrs
# 4           13          15             0.0             Under 5 Hrs
#
#   AS/PH/SUN %         Premium Hours
# 0         96%  Over 40% premium hrs
# ...

# %%
# Filtering with in the file itself to show where Hour per week that are less than 5 and Totals Hrs are less than 10
pahours[(pahours['Hours per week']<5) & (pahours['Total Hrs']<10)]
# Out:
#      SU Ref Basic Hrs SAT Hrs    DON    UON AntiSocial Hrs Pub Hol Hrs  \
# 74     75.0         1    -      -      -                 1        -
# 412   413.0         4    -      -      -                 2        -
# 641   642.0         7    -      -      -                 2        -
# 825   826.0         8    -      -      -              -           -
# 909   910.0         7    -      -      -              -           -
#
#     Sunday Hrs  Total Hrs  Hours per week Hours per week category AS/PH/SUN %  \
# 74        -           2.0             0.0             Under 5 Hrs         67%
# 412       -           6.0             0.0             Under 5 Hrs         36%
# 641       -           9.0             0.0             Under 5 Hrs         22%
# 825       -           8.0             0.0             Under 5 Hrs          0%
# 909       -           7.0             0.0             Under 5 Hrs          0%
#
#             Premium Hours
# 74   Over 40% premium hrs
# 412   21%-40% premium hrs
# ...

# %%
# Slicing to show first 5 rows with SU's and Total hours per week
pahours[0:5][['Pub Hol Hrs','Sunday Hrs']]
# Out:
#   Pub Hol Hrs Sunday Hrs
# 0           5        132
# 1        -           250
# 2           4        112
# 3           2         50
# 4        -            13

# %%
pahours_filtered = pahours.loc[(pahours['Hours per week'] < 5.0) & (pahours['Sunday Hrs'] == '2')]
pahours_filtered.head()
# Out:
#      SU Ref Basic Hrs SAT Hrs    DON    UON AntiSocial Hrs Pub Hol Hrs  \
# 495   496.0       125    -      -      -              -              3
# 637   638.0       102    -      -      -              -              3
# 769   770.0        22    -      -      -              -           -
#
#     Sunday Hrs  Total Hrs  Hours per week Hours per week category AS/PH/SUN %  \
# 495          2      130.0             4.0             Under 5 Hrs          4%
# 637          2      107.0             4.0             Under 5 Hrs          5%
# 769          2       24.0             1.0             Under 5 Hrs          8%
#
#           Premium Hours
# 495  1%-10% premium hrs
# 637  1%-10% premium hrs
# 769  1%-10% premium hrs

# %%
# Dropping duplicate Hours per week. I am  not saving this as a file it self as I want to keet the duplicates
pahours.drop_duplicates(subset='Hours per week')
# Out:
#       SU Ref  Basic Hrs   SAT Hrs    DON    UON   AntiSocial Hrs   \
# 0        1.0           6      -      -      -                   8
# 1        2.0          19      -      -      -                   2
# 2        3.0        -         -      -      -                -
# 3        4.0           6      -      -      -                -
# 4        5.0           2      -      -      -                -
# ...      ...         ...       ...    ...    ...              ...
# 1224  1225.0       1,956      -       212   -                 709
# 1495  1496.0       1,650      -       210   -                 606
# 1563  1564.0         882      -      -       209              760
# 1713  1714.0       1,511      -      -      -                 352
# 1728     NaN         NaN       NaN    NaN    NaN              NaN
#
#       Pub Hol Hrs   Sunday Hrs   Total Hrs   Hours per week  \
# 0                5          132         150             5.0
# ...

# %%
# Dropping Nulls Summerised
pahours.isna().sum()
# Out:
# SU Ref                     1
# Basic Hrs                  1
# SAT Hrs                    1
# DON                        1
# UON                        1
# AntiSocial Hrs             1
# Pub Hol Hrs                1
# Sunday Hrs                 1
# Total Hrs                  1
# Hours per week             1
# Hours per week category    1
# AS/PH/SUN %                1
# Premium Hours              1
# dtype: int64

# %%
pahours.info
# Out:
# <bound method DataFrame.info of       SU Ref  Basic Hrs   SAT Hrs    DON    UON   AntiSocial Hrs   \
# 0        1.0           6      -      -      -                   8
# 1        2.0          19      -      -      -                   2
# 2        3.0        -         -      -      -                -
# 3        4.0           6      -      -      -                -
# 4        5.0           2      -      -      -                -
# ...      ...         ...       ...    ...    ...              ...
# 1724  1725.0          51      -      -      -                  89
# 1725  1726.0         184      -      -      -                 178
# 1726  1727.0        -         -         0   -                -
# 1727  1728.0         465      -      -      -                 357
# 1728     NaN         NaN       NaN    NaN    NaN              NaN
#
#       Pub Hol Hrs   Sunday Hrs   Total Hrs   Hours per week  \
# 0                5          132         150             5.0
# ...

# %%
# Getting the mean os the 'Hours per week'
Hours_per_week=pahours.groupby('Hours per week').mean()
Hours_per_week.head()
# Out:
#                     SU Ref   Total Hrs
# Hours per week
# 0.0             508.888889    9.000000
# 1.0             640.456140   31.982456
# 2.0             624.500000   59.350000
# 3.0             670.186667   90.026667
# 4.0             605.579545  118.681818

# %%
# Bulid a Data Frame, Dictionay as a List. The number of glasses of wine somebody drinks 4 people per week drink
Gwine={'Name':['Tom','Mary','Pat','Mark'],'Monday' :[2,5,7,8], 'Tuesday': [3,2,4,1], 'Wednesday':[1,4,2,6],'Thursday':[3,2,4,1],'Friday':[1,4,3,2],'Saturday':[4,5,7,6],'Sunday':[3,2,5,4]}
Gwine
# Out:
# {'Name': ['Tom', 'Mary', 'Pat', 'Mark'],
#  'Monday': [2, 5, 7, 8],
#  'Tuesday': [3, 2, 4, 1],
#  'Wednesday': [1, 4, 2, 6],
#  'Thursday': [3, 2, 4, 1],
#  'Friday': [1, 4, 3, 2],
#  'Saturday': [4, 5, 7, 6],
#  'Sunday': [3, 2, 5, 4]}

# %%
pd.DataFrame(Gwine)
# Out:
#    Name  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 0   Tom       2        3          1         3       1         4       3
# 1  Mary       5        2          4         2       4         5       2
# 2   Pat       7        4          2         4       3         7       5
# 3  Mark       8        1          6         1       2         6       4

# %%
Gwine2={'Name':['Tip','Edd','Joe','Mick'],'Monday' :[1,7,2,3], 'Tuesday': [3,2,4,1], 'Wednesday':[5,4,2,3],'Thursday':[6,2,2,1],'Friday':[1,4,7,1],'Saturday':[4,5,7,6],'Sunday':[3,2,5,4]}
Gwine2
pd.DataFrame(Gwine2)
# Out:
#    Name  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 0   Tip       1        3          5         6       1         4       3
# 1   Edd       7        2          4         2       4         5       2
# 2   Joe       2        4          2         2       7         7       5
# 3  Mick       3        1          3         1       1         6       4

# %%
Lable1 = pd.DataFrame(Gwine2).set_index('Name')
Lable1
# Out:
#       Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# Name
# Tip        1        3          5         6       1         4       3
# Edd        7        2          4         2       4         5       2
# Joe        2        4          2         2       7         7       5
# Mick       3        1          3         1       1         6       4

# %%
Lable2 = pd.DataFrame(Gwine).set_index('Name')
Lable2
# Out:
#       Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# Name
# Tom        2        3          1         3       1         4       3
# Mary       5        2          4         2       4         5       2
# Pat        7        4          2         4       3         7       5
# Mark       8        1          6         1       2         6       4

# %%
pd.concat([Lable1, Lable2])
# Out:
#    Name  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 0   Tip       1        3          5         6       1         4       3
# 1   Edd       7        2          4         2       4         5       2
# 2   Joe       2        4          2         2       7         7       5
# 3  Mick       3        1          3         1       1         6       4
# 0   Tom       2        3          1         3       1         4       3
# 1  Mary       5        2          4         2       4         5       2
# 2   Pat       7        4          2         4       3         7       5
# 3  Mark       8        1          6         1       2         6       4

# %%
Lable1 = pd.DataFrame(Gwine2)
Lable1
# Out:
#    Name  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 0   Tip       1        3          5         6       1         4       3
# 1   Edd       7        2          4         2       4         5       2
# 2   Joe       2        4          2         2       7         7       5
# 3  Mick       3        1          3         1       1         6       4

# %%
Lable2 = pd.DataFrame(Gwine)
Lable2
# Out:
#    Name  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 0   Tom       2        3          1         3       1         4       3
# 1  Mary       5        2          4         2       4         5       2
# 2   Pat       7        4          2         4       3         7       5
# 3  Mark       8        1          6         1       2         6       4

# %%
Lable1.merge(Lable2, how='outer')
# Out:
#    Name  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 0   Tip       1        3          5         6       1         4       3
# 1   Edd       7        2          4         2       4         5       2
# 2   Joe       2        4          2         2       7         7       5
# 3  Mick       3        1          3         1       1         6       4
# 4   Tom       2        3          1         3       1         4       3
# 5  Mary       5        2          4         2       4         5       2
# 6   Pat       7        4          2         4       3         7       5
# 7  Mark       8        1          6         1       2         6       4

# %%
w1={"Name":['Tom','Mary','Pat','Mark'],"Monday" :[2,5,7,8]}
w1
pd.DataFrame(w1)
# Out:
#    Name  Monday
# 0   Tom       2
# 1  Mary       5
# 2   Pat       7
# 3  Mark       8

# %%
w2={"Name":['Tip','Edd','Joe','Mick'],"Monday" :[1,7,2,3]}
w2
pd.DataFrame(w2)
# Out:
#    Name  Monday
# 0   Tip       1
# 1   Edd       7
# 2   Joe       2
# 3  Mick       3

# %%
# People in Space Station (piss) API's
piss = requests.get('http://api.open-notify.org/astros.json/')
piss
# Out:
# <Response [200]>

# %%
piss = piss.json()
piss
# Out:
# {'people': [{'craft': 'Shenzhou 13', 'name': 'Zhai Zhigang'},
#   {'craft': 'Shenzhou 13', 'name': 'Wang Yaping'},
#   {'craft': 'Shenzhou 13', 'name': 'Ye Guangfu'},
#   {'craft': 'ISS', 'name': 'Raja Chari'},
#   {'craft': 'ISS', 'name': 'Tom Marshburn'},
#   {'craft': 'ISS', 'name': 'Kayla Barron'},
#   {'craft': 'ISS', 'name': 'Matthias Maurer'},
#   {'craft': 'ISS', 'name': 'Oleg Artemyev'},
#   {'craft': 'ISS', 'name': 'Denis Matveev'},
#   {'craft': 'ISS', 'name': 'Sergey Korsakov'},
#   {'craft': 'ISS', 'name': 'Michael Lopez-Alegria'},
#   {'craft': 'ISS', 'name': 'Larry Connor'},
#   {'craft': 'ISS', 'name': 'Mark Pathy'},
#   {'craft': 'ISS', 'name': 'Eytan Stibbe'}],
#  'message': 'success',
#  'number': 14}

# %%
import pandas as pd

# %%
pd.DataFrame(piss['people'])
# Out:
#           craft                   name
# 0   Shenzhou 13           Zhai Zhigang
# 1   Shenzhou 13            Wang Yaping
# 2   Shenzhou 13             Ye Guangfu
# 3           ISS             Raja Chari
# 4           ISS          Tom Marshburn
# 5           ISS           Kayla Barron
# 6           ISS        Matthias Maurer
# 7           ISS          Oleg Artemyev
# 8           ISS          Denis Matveev
# 9           ISS        Sergey Korsakov
# 10          ISS  Michael Lopez-Alegria
# 11          ISS           Larry Connor
# 12          ISS             Mark Pathy
# 13          ISS           Eytan Stibbe

# %%
RTESport = requests.get('https://www.rte.ie/sport/')
RTESport
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup as bs

# %%
Sport = bs(RTESport.content, 'lxml')
Sport.title.text
# Out:
# 'Irish & International Sports News, Fixtures & Results | RTÉ'

# %%
class="temperature">14°C</span>
c

# %%
temp = Sport.find("span",{'class':"temperature"})

# %%
temp.text
# Out:
# ''

# %%
sns.scatterplot(data=pahours, y='Hours per week', x='AS/PH/SUN %')
# Out:
# <AxesSubplot:xlabel='AS/PH/SUN %', ylabel='Hours per week'>

# %%
sns.lmplot(data=pahours, x='SU Ref', y='Total Hrs')
